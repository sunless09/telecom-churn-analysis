# %%
from scipy import stats
import numpy as np

# Версия A: 50 кликов из 1000 показов
clicks_A = 500
views_A = 10000

# Версия B: 65 кликов из 1000 показов
clicks_B = 650
views_B = 10000

# Z-тест для двух пропорций
count = np.array([clicks_A, clicks_B])
nobs = np.array([views_A, views_B])

from statsmodels.stats.proportion import proportions_ztest
z_stat, p_value = proportions_ztest(count, nobs)

print(f"Z-статистика: {z_stat:.4f}")
print(f"p-value: {p_value:.4f}")

if p_value < 0.05:
    print("Разница статистически значима")
else:
    print("Разница НЕ значима — может быть случайностью")
# Out:
# Z-статистика: -4.5562
# p-value: 0.0000
# Разница статистически значима

# %%
import pandas as pd

# Запасной вариант — датасет про отток клиентов телеком-компании,
# тоже отлично подходит для тренировки (похожая логика: предсказание поведения клиента)
url = "https://raw.githubusercontent.com/IBM/telco-customer-churn-on-icp4d/master/data/Telco-Customer-Churn.csv"
df = pd.read_csv(url)


df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
import pandas as pd

# Запасной вариант — датасет про отток клиентов телеком-компании,
# тоже отлично подходит для тренировки (похожая логика: предсказание поведения клиента)
url = "https://raw.githubusercontent.com/IBM/telco-customer-churn-on-icp4d/master/data/Telco-Customer-Churn.csv"
df = pd.read_csv(url)


df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

df = df.dropna(subset=['TotalCharges'])
print(df.shape)
df.groupby('Contract')['Churn'].value_counts(normalize=True)
df.groupby('Churn')['MonthlyCharges'].agg(['mean', 'count', 'sum'])
df.groupby('Contract')['MonthlyCharges'].mean()
# Out:
# (7032, 21)
# Contract
# Month-to-month    66.398490
# One year          65.079416
# Two year          60.872374
# Name: MonthlyCharges, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# График 1 — отток по типу контракта
sns.countplot(data=df, x='Contract', hue='Churn', ax=axes[0])
axes[0].set_title('Отток по типу контракта')
axes[0].set_xlabel('Тип контракта')
axes[0].set_ylabel('Количество клиентов')

# График 2 — распределение MonthlyCharges по оттоку
sns.boxplot(data=df, x='Churn', y='MonthlyCharges', ax=axes[1])
axes[1].set_title('Ежемесячный платёж: ушедшие vs оставшиеся')
axes[1].set_xlabel('Ушёл клиент')
axes[1].set_ylabel('Ежемесячный платёж')

plt.tight_layout()
plt.show()

# %%
df.groupby('Churn')['tenure'].agg(['mean', 'median'])
# Out:
#             mean  median
# Churn
# No     37.650010    38.0
# Yes    17.979133    10.0

# %%
fig, ax = plt.subplots(figsize=(10, 5))

df[df['Churn'] == 'No']['tenure'].hist(bins=30, alpha=0.6, label='Остались', ax=ax)
df[df['Churn'] == 'Yes']['tenure'].hist(bins=30, alpha=0.6, label='Ушли', ax=ax)

ax.set_title('Распределение срока жизни клиента (tenure)')
ax.set_xlabel('Месяцев с компанией')
ax.set_ylabel('Количество клиентов')
ax.legend()

plt.tight_layout()
plt.show()
